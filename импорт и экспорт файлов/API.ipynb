# %% [markdown]
# # Работа с API
#  Добавить страницу в мои закладки
# ✍ В предыдущих разделах мы собирали полезную информацию с различных сайтов.
#
# Вы могли убедиться, что поиск необходимой информации с выделением правильных тегов — довольно трудоёмкая задача. Кроме того, подобные программы могут ломаться в случаях, когда меняется дизайн сайта, его разметка или владельцы сайтов защищаются от ботов капчей.
#
# К счастью, многие крупные сайты предоставляют доступ к так называемым API (англ. Application Programming Interface, рус. Интерфейс Прикладного Программирования).
#
# API — это специальные разделы сайта, где информацию можно получать без разметки, а формат запросов и ответов зафиксирован. API созданы для того, чтобы облегчить взаимодействие с сайтом для сторонних разработчиков.
#
# К примеру, мы уже видели, как ресурс Курсы валют ЦБ РФ в XML и JSON возвращает данные о валютах в JSON-формате. Это пример API.
#
# Рассмотрим на примере социальной сети ВКонтакте особенности API, характерные для более крупных сайтов.
# КЛЮЧ АВТОРИЗАЦИИ
#
# Для того чтобы начать работать с API, обычно необходимо получить сервисный ключ авторизации — токен.
#
# Токен — это средство идентификации пользователя или отдельного сеанса работы в компьютерных сетях и приложениях. Различают программные и аппаратные токены.
# Мы будем использовать программный токен, который обычно представляет собой зашифрованную последовательность символов, позволяющую точно идентифицировать объект и определить уровень его привилегий. Он генерируется системой авторизации и привязывается к конкретному сеансу работы, клиенту сети или пакету данных.
#
# Авторизация применяется практически во всех API, чтобы отдавать данные только их владельцу или контролировать количество запросов в единицу времени.
#
# Сервисный токен для API ВКонтакте для нашей задачи создаётся вместе с новым приложением. Приложение мы делать, конечно, не будем. Оно нужно только для получения токена, чтобы сделать необходимые выгрузки.
#
# Зайдите на страницу, чтобы создать приложение (вы должны быть авторизованы ВКонтакте). Дайте приложению любое название и в разделе Платформа поставьте отметку выбора напротив значения Standalone-приложение:
#
# ![Alt text](https://lms.skillfactory.ru/assets/courseware/v1/f82c440554ddf1bb53c532f5092a4766/asset-v1%3ASkillFactory%2BDST-3.0%2B28FEB2021%2Btype%40asset%2Bblock/Python_17_22.jpg)
# Подтвердив создание приложения на сайте в приложении ВКонтакте или по СМС, зайдите в Настройки. Нужный нам токен лежит в поле Сервисный ключ доступа:
#
# ![Alt text](https://lms.skillfactory.ru/assets/courseware/v1/d751786d3ae76105c314a9511f58e186/asset-v1%3ASkillFactory%2BDST-3.0%2B28FEB2021%2Btype%40asset%2Bblock/Python_17_23.jpg)
#
# ПЕРВЫЕ ЗАПРОСЫ К API
#
# Чтобы познакомиться с работой API, мы будем получать данные для статистических отчётов произвольной группы, например данные о соотношении мужчин и женщин, статистику географии пользователей и т. п.
#
# Сначала рассмотрим работу API на простом примере, на основе которого работают многие системы.
#
# Сделаем наш первый запрос из браузера.
#
# Перейдите по следующей ниже ссылке в браузере, подставив вместо слова TOKEN ваш персональный сервисный ключ доступа (токен), полученный на предыдущем шаге:
# https://api.vk.com/method/users.get?user_id=1&v=5.95&access_token=aa503394aa503394aa5033946ea9418302aaa50aa503394c9d7072cfa516048de32f784
#
# Результат:
#
# Итак, мы сделали GET-запрос к API ВКонтакте, который состоит из следующих элементов:
#
# https://api.vk.com/method — домен и URL запроса API; обычно не меняется;
# users.get — название метода, который отдаёт определённый отчёт, в нашем случае это метод для получения информации о пользователе;
# user_id и v — параметры запроса: идентификатор пользователя, о котором хотим получить информацию (в нашем примере мы запрашиваем информацию о первом пользователе), и номер версии API;
# token — токен, который выдаётся только пользователям, имеющим право просматривать определённые данные, например показания счётчиков Яндекс.Метрики вашего проекта; на все остальные запросы без корректного токена система отвечает отказом.
# Если мы обратимся к документации метод
# а users.get, то увидим, что в ней описано множество других параметров, которые можно получить о пользователе (дата рождения, пол, родной город и другие) — словом, всё то, что мы видим на странице пользователя в интерфейсе или приложении ВКонтакте (конечно, если пользователь их указал).
#
# Добавим к запросу дату рождения и пол (согласно документации, эти параметры надо перечислять в поле fields):
#
# https://api.vk.com/method/users.get?user_id=1&v=5.95&fields=sex,bdate&access_token=TOKEN
#
#
# Примечание: значение 2 у параметра sex означает мужской пол.
#
# До этого момента мы делали запросы в браузере — теперь давайте выполним запросы из кода.
#
# ЗАПРОС К API ИЗ КОДА
#
# Продолжаем пользоваться всё той же библиотекой requests.

# %%
import requests # Импортируем модуль requests
token = 'aa503394aa503394aa5033946ea9418302aaa50aa503394c9d7072cfa516048de32f784' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/users.get' # Указываем адрес страницы к которой делаем запрос
params = {'user_id': 1, 'v': 5.95, 'fields': 'sex,bdate', 'access_token': token, 'lang': 'ru'} # Перечисляем параметры нашего запроса в словаре params
response = requests.get(url, params=params) # Отправляем запрос
print(response.text) # Выводим текст ответа на экран

from pprint import pprint # Импортируем функцию pprint()
pprint(response.json()) 

user = response.json()['response'][0] # Извлекаем из словаря по ключу response информацию о первом пользователе
print(user['bdate'])
# Out:
# {"response":[{"id":1,"bdate":"10.10.1984","sex":2,"first_name":"Павел","last_name":"Дуров","can_access_closed":true,"is_closed":false}]}
# {'response': [{'bdate': '10.10.1984',
#                'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров',
#                'sex': 2}]}
# 10.10.1984

# %% [markdown]
# Метод users.get() позволяет запрашивать информацию о множестве (до 1 000) пользователей одновременно. Для этого нужно использовать параметр user_ids и передавать id через запятую в строковом формате. Например, чтобы получить информацию о пользователях с id=1, id=2, id=3, необходимо передать значение параметра user_ids='1,2,3'.
#
# Попробуем это сделать:

# %%
ids = ",".join(map(str, range(1, 4))) # Формируем строку, содержащую информацию о поле id первых трёх пользователей
params = {'user_ids': ids, 'v': 5.95, 'fields': 'bday', 'access_token': token, 'lang': 'ru'} # Формируем строку параметров


ids1 = ','.join(map(str, range(1,501)))
params1 = {'user_ids': ids1, 'v': 5.95, 'fields': 'sex', 'access_token': token, 'lang': 'ru'}
url = 'https://api.vk.com/method/users.get'
response = requests.get(url, params=params1)
users = response.json()
pprint(users['response'])
men=women=0
for i in users['response']:
    if i['sex'] == 1:
        women+=1
    if i['sex'] == 2:
        men+=1
print(round(women/(men+women),2))
# Out:
# [{'can_access_closed': True,
#   'first_name': 'Павел',
#   'id': 1,
#   'is_closed': False,
#   'last_name': 'Дуров',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Александра',
#   'id': 2,
#   'is_closed': True,
#   'last_name': 'Владимирова',
#   'sex': 1},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 3,
#   'last_name': '',
#   'sex': 0},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 4,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Илья',
#   'id': 5,
#   'is_closed': False,
#   'last_name': 'Перекопский',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Николай',
#   'id': 6,
#   'is_closed': False,
#   'last_name': 'Дуров',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Алексей',
#   'id': 7,
#   'is_closed': True,
#   'last_name': 'Кобылянский',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Аки',
#   'id': 8,
#   'is_closed': False,
#   'last_name': 'Сепиашвили',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Настя',
#   'id': 9,
#   'is_closed': True,
#   'last_name': 'Васильева',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Александр',
#   'id': 10,
#   'is_closed': True,
#   'last_name': 'Кузнецов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Михаил',
#   'id': 11,
#   'is_closed': False,
#   'last_name': 'Петров',
#   'sex': 2},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 12,
#   'last_name': '',
#   'sex': 2},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 13,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Андрей',
#   'id': 14,
#   'is_closed': False,
#   'last_name': 'Городецкий',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Сергей',
#   'id': 15,
#   'is_closed': True,
#   'last_name': 'Васильков',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Виктория',
#   'id': 16,
#   'is_closed': True,
#   'last_name': 'Беспалова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Александр',
#   'id': 17,
#   'is_closed': False,
#   'last_name': 'Беспалов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Симон',
#   'id': 18,
#   'is_closed': False,
#   'last_name': 'Кречмер',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Светочек',
#   'id': 19,
#   'is_closed': False,
#   'last_name': 'Аленький',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Илья',
#   'id': 20,
#   'is_closed': True,
#   'last_name': 'Турпиашвили',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Михаил',
#   'id': 21,
#   'is_closed': False,
#   'last_name': 'Равдоникас',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Семен',
#   'id': 22,
#   'is_closed': False,
#   'last_name': 'Воронин',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Андрей',
#   'id': 23,
#   'is_closed': False,
#   'last_name': 'Столбовский',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Рамми',
#   'id': 24,
#   'is_closed': True,
#   'last_name': 'Цицуашвили',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Анастасия',
#   'id': 25,
#   'is_closed': True,
#   'last_name': 'Ведущенко',
#   'sex': 1},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 26,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Юлия',
#   'id': 27,
#   'is_closed': False,
#   'last_name': 'Семиколенова',
#   'sex': 1},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 28,
#   'last_name': '',
#   'sex': 0},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 29,
#   'last_name': '',
#   'sex': 0},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 30,
#   'last_name': '',
#   'sex': 0},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 31,
#   'last_name': '',
#   'sex': 0},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 32,
#   'last_name': '',
#   'sex': 0},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 33,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': False,
#   'first_name': 'Татьяна',
#   'id': 34,
#   'is_closed': True,
#   'last_name': 'Плуталова',
#   'sex': 1},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 35,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Иван',
#   'id': 36,
#   'is_closed': False,
#   'last_name': 'Смирнов',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Михаил',
#   'id': 37,
#   'is_closed': True,
#   'last_name': 'Казекин',
#   'sex': 2},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 38,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'David',
#   'id': 39,
#   'is_closed': False,
#   'last_name': 'Mirelli',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Олег',
#   'id': 40,
#   'is_closed': False,
#   'last_name': 'Чередников',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Владислав',
#   'id': 41,
#   'is_closed': False,
#   'last_name': 'Миллер',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Сергей',
#   'id': 42,
#   'is_closed': False,
#   'last_name': 'Маркин',
#   'sex': 2},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 43,
#   'last_name': '',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Тамара',
#   'id': 44,
#   'is_closed': False,
#   'last_name': 'Мирилашвили',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Сергей',
#   'id': 45,
#   'is_closed': False,
#   'last_name': 'Виноградов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Андрей',
#   'id': 46,
#   'is_closed': False,
#   'last_name': 'Лесохин',
#   'sex': 2},
#  {'deactivated': 'banned',
#   'first_name': 'Габриел',
#   'id': 47,
#   'last_name': 'Шалел',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Миша',
#   'id': 48,
#   'is_closed': False,
#   'last_name': 'Мельников',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Бот',
#   'id': 49,
#   'is_closed': False,
#   'last_name': 'Мороз',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Снегурочка',
#   'id': 50,
#   'is_closed': False,
#   'last_name': 'Морозова',
#   'sex': 1},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 51,
#   'last_name': '',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Михаил',
#   'id': 52,
#   'is_closed': False,
#   'last_name': 'Вознесенский',
#   'sex': 2},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 53,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Екатерина',
#   'id': 54,
#   'is_closed': False,
#   'last_name': 'Фуртикова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Андрей',
#   'id': 55,
#   'is_closed': False,
#   'last_name': 'Смирнов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Андрей',
#   'id': 56,
#   'is_closed': False,
#   'last_name': 'Чернышев',
#   'sex': 2},
#  {'deactivated': 'deleted',
#   'first_name': 'Сергей',
#   'id': 57,
#   'last_name': 'Владимиров',
#   'sex': 2},
#  {'deactivated': 'banned',
#   'first_name': 'Александр',
#   'id': 58,
#   'last_name': 'Ковалев',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Анастасия',
#   'id': 59,
#   'is_closed': False,
#   'last_name': 'Желудкова',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Даниэль',
#   'id': 60,
#   'is_closed': True,
#   'last_name': 'Розенберг',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Григорий',
#   'id': 61,
#   'is_closed': False,
#   'last_name': 'Конрадт',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Анастасия',
#   'id': 62,
#   'is_closed': False,
#   'last_name': 'Ланина',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Никита',
#   'id': 63,
#   'is_closed': True,
#   'last_name': 'Поликарпов',
#   'sex': 2},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 64,
#   'last_name': '',
#   'sex': 0},
#  {'deactivated': 'banned',
#   'first_name': 'Mikhail',
#   'id': 65,
#   'last_name': 'Torline',
#   'sex': 2},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 66,
#   'last_name': '',
#   'sex': 0},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 67,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Вика',
#   'id': 68,
#   'is_closed': False,
#   'last_name': 'Мирилашвили',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Avi',
#   'id': 69,
#   'is_closed': True,
#   'last_name': 'Shalel',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Митя',
#   'id': 70,
#   'is_closed': False,
#   'last_name': 'Миронов',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Людмила',
#   'id': 71,
#   'is_closed': True,
#   'last_name': 'Романченко',
#   'sex': 1},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 72,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': False,
#   'first_name': 'Надежда',
#   'id': 73,
#   'is_closed': True,
#   'last_name': 'Лебедева',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Наташа',
#   'id': 74,
#   'is_closed': False,
#   'last_name': 'Филимонова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Екатерина',
#   'id': 75,
#   'is_closed': False,
#   'last_name': 'Копылова',
#   'sex': 1},
#  {'deactivated': 'banned',
#   'first_name': 'David',
#   'id': 76,
#   'last_name': 'Biniaurischwili',
#   'sex': 2},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 77,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': False,
#   'first_name': 'Анна',
#   'id': 78,
#   'is_closed': True,
#   'last_name': 'Руднева',
#   'sex': 1},
#  {'deactivated': 'banned',
#   'first_name': 'Давид',
#   'id': 79,
#   'last_name': 'Спектер',
#   'sex': 2},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 80,
#   'last_name': '',
#   'sex': 0},
#  {'deactivated': 'banned',
#   'first_name': 'Влад',
#   'id': 81,
#   'last_name': 'Куценко',
#   'sex': 2},
#  {'deactivated': 'banned',
#   'first_name': 'Tami',
#   'id': 82,
#   'last_name': 'Shalel',
#   'sex': 2},
#  {'deactivated': 'banned',
#   'first_name': 'Дмитрий',
#   'id': 83,
#   'last_name': 'Тихомиров',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Фёдор',
#   'id': 84,
#   'is_closed': False,
#   'last_name': 'Медведев',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Mikhail',
#   'id': 85,
#   'is_closed': True,
#   'last_name': 'Gennadevich',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Никита',
#   'id': 86,
#   'is_closed': True,
#   'last_name': 'Пиастро',
#   'sex': 2},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 87,
#   'last_name': '',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Полина',
#   'id': 88,
#   'is_closed': False,
#   'last_name': 'Олейник',
#   'sex': 1},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 89,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Малина',
#   'id': 90,
#   'is_closed': False,
#   'last_name': 'Baci',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Дарья',
#   'id': 91,
#   'is_closed': False,
#   'last_name': 'Белинская',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Екатерина',
#   'id': 92,
#   'is_closed': True,
#   'last_name': 'Тихонова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Анна',
#   'id': 93,
#   'is_closed': False,
#   'last_name': 'Забоева',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Екатерина',
#   'id': 94,
#   'is_closed': False,
#   'last_name': 'Теплова',
#   'sex': 1},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 95,
#   'last_name': '',
#   'sex': 0},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 96,
#   'last_name': '',
#   'sex': 0},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 97,
#   'last_name': '',
#   'sex': 0},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 98,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': False,
#   'first_name': 'Наталья',
#   'id': 99,
#   'is_closed': True,
#   'last_name': 'Брагина',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Администрация ВКонтакте',
#   'id': 100,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Администратор',
#   'id': 101,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Екатерина',
#   'id': 102,
#   'is_closed': False,
#   'last_name': 'Тенева',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Анна',
#   'id': 103,
#   'is_closed': False,
#   'last_name': 'Романцева',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Ольга',
#   'id': 104,
#   'is_closed': False,
#   'last_name': 'Ребикова',
#   'sex': 1},
#  {'deactivated': 'banned',
#   'first_name': 'Roman',
#   'id': 105,
#   'last_name': 'Ponomarenko',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Спотти',
#   'id': 106,
#   'is_closed': False,
#   'last_name': 'Космический',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Администрация',
#   'id': 107,
#   'is_closed': True,
#   'last_name': 'Б.',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Диана',
#   'id': 108,
#   'is_closed': True,
#   'last_name': 'Курбатова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Ольга',
#   'id': 109,
#   'is_closed': False,
#   'last_name': 'Горюнова',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Администрация',
#   'id': 110,
#   'is_closed': True,
#   'last_name': 'В.',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Евгения',
#   'id': 111,
#   'is_closed': False,
#   'last_name': 'Лаврова',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Евгения',
#   'id': 112,
#   'is_closed': True,
#   'last_name': 'Алексеева',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Владислав',
#   'id': 113,
#   'is_closed': False,
#   'last_name': 'Умнов',
#   'sex': 2},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 114,
#   'last_name': '',
#   'sex': 0},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 115,
#   'last_name': '',
#   'sex': 0},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 116,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Антон',
#   'id': 117,
#   'is_closed': False,
#   'last_name': 'Краснов',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Светлана',
#   'id': 118,
#   'is_closed': True,
#   'last_name': 'Никулина',
#   'sex': 1},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 119,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Елена',
#   'id': 120,
#   'is_closed': False,
#   'last_name': 'Соколова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Надежда',
#   'id': 121,
#   'is_closed': False,
#   'last_name': 'Сторчевая',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Надежда',
#   'id': 122,
#   'is_closed': True,
#   'last_name': 'Игошина',
#   'sex': 1},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 123,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Екатерина',
#   'id': 124,
#   'is_closed': False,
#   'last_name': 'Горбунова',
#   'sex': 1},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 125,
#   'last_name': '',
#   'sex': 0},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 126,
#   'last_name': '',
#   'sex': 0},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 127,
#   'last_name': '',
#   'sex': 0},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 128,
#   'last_name': '',
#   'sex': 0},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 129,
#   'last_name': '',
#   'sex': 0},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 130,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': False,
#   'first_name': 'Шурикен',
#   'id': 131,
#   'is_closed': True,
#   'last_name': 'Картошкин',
#   'sex': 2},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 132,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Николай',
#   'id': 133,
#   'is_closed': False,
#   'last_name': 'Харчев',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Илико',
#   'id': 134,
#   'is_closed': False,
#   'last_name': 'Шаптай',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Мария',
#   'id': 135,
#   'is_closed': False,
#   'last_name': 'Филатова',
#   'sex': 1},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 136,
#   'last_name': '',
#   'sex': 0},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 137,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Алексей',
#   'id': 138,
#   'is_closed': False,
#   'last_name': 'Рощин',
#   'sex': 2},
#  {'deactivated': 'banned',
#   'first_name': 'Роман',
#   'id': 139,
#   'last_name': 'Чистяков',
#   'sex': 2},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 140,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': False,
#   'first_name': 'Сергей',
#   'id': 141,
#   'is_closed': True,
#   'last_name': 'Михайлов',
#   'sex': 2},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 142,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Машечка',
#   'id': 143,
#   'is_closed': False,
#   'last_name': 'Зайцева',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Oleg',
#   'id': 144,
#   'is_closed': False,
#   'last_name': 'Zinkevich',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Константин',
#   'id': 145,
#   'is_closed': False,
#   'last_name': 'Теплов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Александра',
#   'id': 146,
#   'is_closed': False,
#   'last_name': 'Муромцева',
#   'sex': 1},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 147,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Артём',
#   'id': 148,
#   'is_closed': False,
#   'last_name': 'Абанин',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Сергей',
#   'id': 149,
#   'is_closed': False,
#   'last_name': 'Лобакин',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Луиза',
#   'id': 150,
#   'is_closed': False,
#   'last_name': 'Левиева',
#   'sex': 1},
#  {'deactivated': 'banned',
#   'first_name': 'Леонид',
#   'id': 151,
#   'last_name': 'Добронов',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Илара',
#   'id': 152,
#   'is_closed': True,
#   'last_name': 'Юнаева',
#   'sex': 1},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 153,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': False,
#   'first_name': 'Елисей',
#   'id': 154,
#   'is_closed': True,
#   'last_name': 'Замахов',
#   'sex': 2},
#  {'deactivated': 'banned',
#   'first_name': 'Dennis',
#   'id': 155,
#   'last_name': 'Yurlov',
#   'sex': 2},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 156,
#   'last_name': '',
#   'sex': 0},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 157,
#   'last_name': '',
#   'sex': 0},
#  {'deactivated': 'banned',
#   'first_name': 'Владислав',
#   'id': 158,
#   'last_name': 'Гатилов',
#   'sex': 2},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 159,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': False,
#   'first_name': 'Васильев',
#   'id': 160,
#   'is_closed': True,
#   'last_name': 'Сергеевич',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Валентина',
#   'id': 161,
#   'is_closed': False,
#   'last_name': 'Савосина',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Александра',
#   'id': 162,
#   'is_closed': False,
#   'last_name': 'Аленичева',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Анастасия',
#   'id': 163,
#   'is_closed': True,
#   'last_name': 'Романько',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Алексей',
#   'id': 164,
#   'is_closed': True,
#   'last_name': 'Ткаченко',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Иван',
#   'id': 165,
#   'is_closed': False,
#   'last_name': 'Романько',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Дмитрий',
#   'id': 166,
#   'is_closed': False,
#   'last_name': 'Коменденко',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Демид',
#   'id': 167,
#   'is_closed': False,
#   'last_name': 'Кириленко',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Вероника',
#   'id': 168,
#   'is_closed': False,
#   'last_name': 'Кириленко',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Ольга',
#   'id': 169,
#   'is_closed': False,
#   'last_name': 'Чистоклетова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Богдан',
#   'id': 170,
#   'is_closed': False,
#   'last_name': 'Жидков',
#   'sex': 2},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 171,
#   'last_name': '',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Aleksei',
#   'id': 172,
#   'is_closed': True,
#   'last_name': 'Gorodetskii',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Мария',
#   'id': 173,
#   'is_closed': False,
#   'last_name': 'Чепурная',
#   'sex': 1},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 174,
#   'last_name': '',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Михаил',
#   'id': 175,
#   'is_closed': False,
#   'last_name': 'Захаренков',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Иван',
#   'id': 176,
#   'is_closed': False,
#   'last_name': 'Смирнов',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Екатерина',
#   'id': 177,
#   'is_closed': True,
#   'last_name': 'Абраменко',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Марья',
#   'id': 178,
#   'is_closed': True,
#   'last_name': 'Безносова',
#   'sex': 1},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 179,
#   'last_name': '',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Владимир',
#   'id': 180,
#   'is_closed': False,
#   'last_name': 'Корнев',
#   'sex': 2},
#  {'deactivated': 'banned',
#   'first_name': 'Андрей',
#   'id': 181,
#   'last_name': 'Матвеев',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Николай',
#   'id': 182,
#   'is_closed': False,
#   'last_name': 'Андреев',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Ольга',
#   'id': 183,
#   'is_closed': False,
#   'last_name': 'Кретова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Анастасия',
#   'id': 184,
#   'is_closed': False,
#   'last_name': 'Владимирова',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Вадим',
#   'id': 185,
#   'is_closed': True,
#   'last_name': 'Рудковский',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Ольга',
#   'id': 186,
#   'is_closed': False,
#   'last_name': 'Савинкина-Титова',
#   'sex': 1},
#  {'deactivated': 'banned',
#   'first_name': 'Сергей',
#   'id': 187,
#   'last_name': 'Воскресенкий',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Евгений',
#   'id': 188,
#   'is_closed': True,
#   'last_name': 'Лыков',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Вероника',
#   'id': 189,
#   'is_closed': False,
#   'last_name': 'Лежнева',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Вадим',
#   'id': 190,
#   'is_closed': False,
#   'last_name': 'Колосов',
#   'sex': 2},
#  {'deactivated': 'banned',
#   'first_name': 'Гена',
#   'id': 191,
#   'last_name': 'Загальский',
#   'sex': 2},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 192,
#   'last_name': '',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Иван',
#   'id': 193,
#   'is_closed': False,
#   'last_name': 'Кораблев-Дайсон',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Сергей',
#   'id': 194,
#   'is_closed': True,
#   'last_name': 'Гребнев',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Михаил',
#   'id': 195,
#   'is_closed': False,
#   'last_name': 'Келим',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Екатерина',
#   'id': 196,
#   'is_closed': True,
#   'last_name': 'Караваева',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Дарья',
#   'id': 197,
#   'is_closed': True,
#   'last_name': 'Бондаренко',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Вальтер',
#   'id': 198,
#   'is_closed': True,
#   'last_name': 'Киршнер',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Елена',
#   'id': 199,
#   'is_closed': True,
#   'last_name': 'Жигалова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Андрей',
#   'id': 200,
#   'is_closed': False,
#   'last_name': 'Стрельников',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Игнатий',
#   'id': 201,
#   'is_closed': False,
#   'last_name': 'Дьяков',
#   'sex': 2},
#  {'deactivated': 'banned',
#   'first_name': 'Максим',
#   'id': 202,
#   'last_name': 'Ластовка',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Зоя',
#   'id': 203,
#   'is_closed': False,
#   'last_name': 'Барабанова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Юлия',
#   'id': 204,
#   'is_closed': False,
#   'last_name': 'Скрябина',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Ирина',
#   'id': 205,
#   'is_closed': True,
#   'last_name': 'Ямщикова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Юрий',
#   'id': 206,
#   'is_closed': False,
#   'last_name': 'Скрелин',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Yulia',
#   'id': 207,
#   'is_closed': False,
#   'last_name': 'Bekmukhamedova',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Гена',
#   'id': 208,
#   'is_closed': True,
#   'last_name': 'Зарохин',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Елена',
#   'id': 209,
#   'is_closed': False,
#   'last_name': 'Дьячкова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Аня',
#   'id': 210,
#   'is_closed': False,
#   'last_name': 'Дормидонтова',
#   'sex': 1},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 211,
#   'last_name': '',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Алёна',
#   'id': 212,
#   'is_closed': False,
#   'last_name': 'Фёдорова',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Максим',
#   'id': 213,
#   'is_closed': True,
#   'last_name': 'Казанский',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Андрей',
#   'id': 214,
#   'is_closed': False,
#   'last_name': 'Зелёный',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Екатерина',
#   'id': 215,
#   'is_closed': False,
#   'last_name': 'Мерзлякова',
#   'sex': 1},
#  {'deactivated': 'banned',
#   'first_name': 'Андрей',
#   'id': 216,
#   'last_name': 'Мирных',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Alexander',
#   'id': 217,
#   'is_closed': False,
#   'last_name': 'Nasyrov',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Oksana',
#   'id': 218,
#   'is_closed': False,
#   'last_name': 'Zotova',
#   'sex': 1},
#  {'deactivated': 'banned',
#   'first_name': 'Роман',
#   'id': 219,
#   'last_name': 'Акамёлков',
#   'sex': 2},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 220,
#   'last_name': '',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Наталья',
#   'id': 221,
#   'is_closed': False,
#   'last_name': 'Курчакова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Анна',
#   'id': 222,
#   'is_closed': False,
#   'last_name': 'Ступина',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Инга',
#   'id': 223,
#   'is_closed': False,
#   'last_name': 'Гладущик',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Ирина',
#   'id': 224,
#   'is_closed': True,
#   'last_name': 'Кирсанова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Елена',
#   'id': 225,
#   'is_closed': False,
#   'last_name': 'Петропавловская',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Антон',
#   'id': 226,
#   'is_closed': True,
#   'last_name': 'Нестеров',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Ася',
#   'id': 227,
#   'is_closed': True,
#   'last_name': 'Лазо',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Дима',
#   'id': 228,
#   'is_closed': True,
#   'last_name': 'Мартиросов',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Гумер',
#   'id': 229,
#   'is_closed': True,
#   'last_name': 'Исаев',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Олеся',
#   'id': 230,
#   'is_closed': False,
#   'last_name': 'Дигина',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Юрий',
#   'id': 231,
#   'is_closed': False,
#   'last_name': 'Бычков',
#   'sex': 2},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 232,
#   'last_name': '',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Варя',
#   'id': 233,
#   'is_closed': False,
#   'last_name': 'Баранова',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Julia',
#   'id': 234,
#   'is_closed': True,
#   'last_name': 'Child',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Фредерик',
#   'id': 235,
#   'is_closed': False,
#   'last_name': 'Булгаков',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Александра',
#   'id': 236,
#   'is_closed': False,
#   'last_name': 'Насекина',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Сергей',
#   'id': 237,
#   'is_closed': True,
#   'last_name': 'Журавлёв',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Татьяна',
#   'id': 238,
#   'is_closed': True,
#   'last_name': 'Тимофеева',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Светлана',
#   'id': 239,
#   'is_closed': True,
#   'last_name': 'Степанова',
#   'sex': 1},
#  {'deactivated': 'banned',
#   'first_name': 'Влад',
#   'id': 240,
#   'last_name': 'Коробейников',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Наташа',
#   'id': 241,
#   'is_closed': False,
#   'last_name': 'Власова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Алексей',
#   'id': 242,
#   'is_closed': False,
#   'last_name': 'Ёжиков',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Екатерина',
#   'id': 243,
#   'is_closed': False,
#   'last_name': 'Лапанович',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Анна',
#   'id': 244,
#   'is_closed': False,
#   'last_name': 'Колдунова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Zhenechka',
#   'id': 245,
#   'is_closed': False,
#   'last_name': 'Pimenofffffff',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Алексей',
#   'id': 246,
#   'is_closed': True,
#   'last_name': 'Попов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Юлия',
#   'id': 247,
#   'is_closed': False,
#   'last_name': 'Гордеева',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Мария',
#   'id': 248,
#   'is_closed': False,
#   'last_name': 'Рейнгольд',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Екатерина',
#   'id': 249,
#   'is_closed': False,
#   'last_name': 'Карпова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Юрий',
#   'id': 250,
#   'is_closed': False,
#   'last_name': 'Бабаин',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Михаил',
#   'id': 251,
#   'is_closed': False,
#   'last_name': 'Чудотворов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Сергей',
#   'id': 252,
#   'is_closed': False,
#   'last_name': 'Микушев',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Karina',
#   'id': 253,
#   'is_closed': True,
#   'last_name': 'Mutlu',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Ася',
#   'id': 254,
#   'is_closed': False,
#   'last_name': 'Щёголь',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Андрей',
#   'id': 255,
#   'is_closed': False,
#   'last_name': 'Уласень',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Ксения',
#   'id': 256,
#   'is_closed': True,
#   'last_name': 'Тинсли',
#   'sex': 1},
#  {'deactivated': 'banned',
#   'first_name': 'Саша',
#   'id': 257,
#   'last_name': 'Дроздовский',
#   'sex': 2},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 258,
#   'last_name': '',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Катерина',
#   'id': 259,
#   'is_closed': True,
#   'last_name': 'Албу',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Анастасия',
#   'id': 260,
#   'is_closed': True,
#   'last_name': 'Графова',
#   'sex': 1},
#  {'deactivated': 'banned',
#   'first_name': 'Nothing',
#   'id': 261,
#   'last_name': 'Personal',
#   'sex': 2},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 262,
#   'last_name': '',
#   'sex': 0},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 263,
#   'last_name': '',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Анна',
#   'id': 264,
#   'is_closed': False,
#   'last_name': 'Пугачёва',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Андрей',
#   'id': 265,
#   'is_closed': False,
#   'last_name': 'Истомин',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Роман',
#   'id': 266,
#   'is_closed': False,
#   'last_name': 'Захаров',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Наталья',
#   'id': 267,
#   'is_closed': True,
#   'last_name': 'Бердникова',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Леонид',
#   'id': 268,
#   'is_closed': True,
#   'last_name': 'Ананьев',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Елена',
#   'id': 269,
#   'is_closed': False,
#   'last_name': 'Миненок',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Ирина',
#   'id': 270,
#   'is_closed': True,
#   'last_name': 'Рыбакова',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Александр',
#   'id': 271,
#   'is_closed': True,
#   'last_name': 'Селиванов',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Павел',
#   'id': 272,
#   'is_closed': True,
#   'last_name': 'Моржов',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Павел',
#   'id': 273,
#   'is_closed': True,
#   'last_name': 'Самойлов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Мария',
#   'id': 274,
#   'is_closed': False,
#   'last_name': 'Тюрина',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Мария',
#   'id': 275,
#   'is_closed': True,
#   'last_name': 'Михайлова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Катарина',
#   'id': 276,
#   'is_closed': False,
#   'last_name': 'Коровникова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Александр',
#   'id': 277,
#   'is_closed': False,
#   'last_name': 'Кузнецов',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Мария',
#   'id': 278,
#   'is_closed': True,
#   'last_name': 'Грей',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Катя',
#   'id': 279,
#   'is_closed': True,
#   'last_name': 'Розенберг',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Вера',
#   'id': 280,
#   'is_closed': True,
#   'last_name': 'Семенова',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Мария',
#   'id': 281,
#   'is_closed': True,
#   'last_name': 'Иванова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Елена',
#   'id': 282,
#   'is_closed': False,
#   'last_name': 'Цимберг',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Елена',
#   'id': 283,
#   'is_closed': False,
#   'last_name': 'Андриенко',
#   'sex': 1},
#  {'deactivated': 'banned',
#   'first_name': 'Александр',
#   'id': 284,
#   'last_name': 'Кузнецов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Анастасия',
#   'id': 285,
#   'is_closed': False,
#   'last_name': 'Столовицкая',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Маргарита',
#   'id': 286,
#   'is_closed': False,
#   'last_name': 'Дмитриева',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Иван',
#   'id': 287,
#   'is_closed': False,
#   'last_name': 'Кондаков',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Сергей',
#   'id': 288,
#   'is_closed': True,
#   'last_name': 'Покровский',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Юлик',
#   'id': 289,
#   'is_closed': False,
#   'last_name': 'Суртаева',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Аркадий',
#   'id': 290,
#   'is_closed': False,
#   'last_name': 'Гуманюк',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Виктор',
#   'id': 291,
#   'is_closed': True,
#   'last_name': 'Танчак',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Анна',
#   'id': 292,
#   'is_closed': False,
#   'last_name': 'Чупира',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Елена',
#   'id': 293,
#   'is_closed': True,
#   'last_name': 'Жеребкова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Татьяна',
#   'id': 294,
#   'is_closed': False,
#   'last_name': 'Учагина-Василенок',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Olga',
#   'id': 295,
#   'is_closed': True,
#   'last_name': 'Sergeecheva',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Екатерина',
#   'id': 296,
#   'is_closed': False,
#   'last_name': 'Вязьменская',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Владимир',
#   'id': 297,
#   'is_closed': False,
#   'last_name': 'Сюткин',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Евгений',
#   'id': 298,
#   'is_closed': False,
#   'last_name': 'Скоробогатько',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Анна',
#   'id': 299,
#   'is_closed': True,
#   'last_name': 'Вишневская',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Юрий',
#   'id': 300,
#   'is_closed': False,
#   'last_name': 'Новичков',
#   'sex': 2},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 301,
#   'last_name': '',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Павел',
#   'id': 302,
#   'is_closed': True,
#   'last_name': 'Биргер',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Оксана',
#   'id': 303,
#   'is_closed': False,
#   'last_name': 'Ласкателева',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Мария',
#   'id': 304,
#   'is_closed': False,
#   'last_name': 'Малашевская',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Павел',
#   'id': 305,
#   'is_closed': True,
#   'last_name': 'Логачев',
#   'sex': 2},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 306,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': False,
#   'first_name': 'Стаська',
#   'id': 307,
#   'is_closed': True,
#   'last_name': 'Титова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Владимир',
#   'id': 308,
#   'is_closed': False,
#   'last_name': 'Степанов',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Ilya',
#   'id': 309,
#   'is_closed': True,
#   'last_name': 'Krivonogov',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Константин',
#   'id': 310,
#   'is_closed': False,
#   'last_name': 'Иванов',
#   'sex': 2},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 311,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': False,
#   'first_name': 'Кузьма',
#   'id': 312,
#   'is_closed': True,
#   'last_name': 'Кукушкин',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Виталий',
#   'id': 313,
#   'is_closed': False,
#   'last_name': 'Шипов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Анна',
#   'id': 314,
#   'is_closed': False,
#   'last_name': 'Прядченко',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Павел',
#   'id': 315,
#   'is_closed': False,
#   'last_name': 'Медведев',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Дарья',
#   'id': 316,
#   'is_closed': False,
#   'last_name': 'Лесохина',
#   'sex': 1},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 317,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Надежда',
#   'id': 318,
#   'is_closed': False,
#   'last_name': 'Сомкина',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Софья',
#   'id': 319,
#   'is_closed': False,
#   'last_name': 'Астраханцева',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Марина',
#   'id': 320,
#   'is_closed': False,
#   'last_name': 'Цветкова',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Анна',
#   'id': 321,
#   'is_closed': True,
#   'last_name': 'Гершон',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Евгений',
#   'id': 322,
#   'is_closed': False,
#   'last_name': 'Соколенко',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Алексей',
#   'id': 323,
#   'is_closed': True,
#   'last_name': 'Орлов',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Анастасия',
#   'id': 324,
#   'is_closed': True,
#   'last_name': 'Логинова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Дмитрий',
#   'id': 325,
#   'is_closed': False,
#   'last_name': 'Желтов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Екатерина',
#   'id': 326,
#   'is_closed': False,
#   'last_name': 'Яроцкая',
#   'sex': 1},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 327,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Аня',
#   'id': 328,
#   'is_closed': False,
#   'last_name': 'Левина',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Светлана',
#   'id': 329,
#   'is_closed': True,
#   'last_name': 'Гончаренко',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Дмитрий',
#   'id': 330,
#   'is_closed': False,
#   'last_name': 'Чернецкий',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Эмиль',
#   'id': 331,
#   'is_closed': False,
#   'last_name': 'Байбагышев',
#   'sex': 2},
#  {'deactivated': 'banned',
#   'first_name': 'Дима',
#   'id': 332,
#   'last_name': 'Зеленцов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Агент Поддержки',
#   'id': 333,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Полина',
#   'id': 334,
#   'is_closed': False,
#   'last_name': 'Богуш',
#   'sex': 1},
#  {'deactivated': 'banned',
#   'first_name': 'Дмитрий',
#   'id': 335,
#   'last_name': 'Овчиннов',
#   'sex': 2},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 336,
#   'last_name': '',
#   'sex': 2},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 337,
#   'last_name': '',
#   'sex': 0},
#  {'deactivated': 'banned',
#   'first_name': 'Андрей',
#   'id': 338,
#   'last_name': 'Власов',
#   'sex': 2},
#  {'deactivated': 'banned',
#   'first_name': 'Виктор',
#   'id': 339,
#   'last_name': 'Вавилов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Oksana',
#   'id': 340,
#   'is_closed': False,
#   'last_name': 'Fimina',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Shmavon',
#   'id': 341,
#   'is_closed': True,
#   'last_name': 'Gazanchyan',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Dmitry',
#   'id': 342,
#   'is_closed': True,
#   'last_name': 'Svetloff',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Алексей',
#   'id': 343,
#   'is_closed': True,
#   'last_name': 'Пилин',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Сергей',
#   'id': 344,
#   'is_closed': False,
#   'last_name': 'Фоминых',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Дарья',
#   'id': 345,
#   'is_closed': True,
#   'last_name': 'Фролова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Полина',
#   'id': 346,
#   'is_closed': False,
#   'last_name': 'Маркина',
#   'sex': 1},
#  {'deactivated': 'banned',
#   'first_name': 'Андрей',
#   'id': 347,
#   'last_name': 'Бойко',
#   'sex': 2},
#  {'deactivated': 'banned',
#   'first_name': 'Галина',
#   'id': 348,
#   'last_name': 'Румянцева',
#   'sex': 1},
#  {'deactivated': 'banned',
#   'first_name': 'Анастасия',
#   'id': 349,
#   'last_name': 'Силюкова',
#   'sex': 1},
#  {'deactivated': 'banned',
#   'first_name': 'Павел',
#   'id': 350,
#   'last_name': 'Таразевич',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Елена',
#   'id': 351,
#   'is_closed': False,
#   'last_name': 'Харламова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Виктория',
#   'id': 352,
#   'is_closed': False,
#   'last_name': 'Казакова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Анна',
#   'id': 353,
#   'is_closed': False,
#   'last_name': 'Овчинникова',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Александра',
#   'id': 354,
#   'is_closed': True,
#   'last_name': 'Alexxandra',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Елена',
#   'id': 355,
#   'is_closed': True,
#   'last_name': 'Бацманова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Арина',
#   'id': 356,
#   'is_closed': False,
#   'last_name': 'Ускова',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Аннет',
#   'id': 357,
#   'is_closed': True,
#   'last_name': 'Григорович',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Екатерина',
#   'id': 358,
#   'is_closed': False,
#   'last_name': 'Фейн',
#   'sex': 1},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 359,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': False,
#   'first_name': 'Мила',
#   'id': 360,
#   'is_closed': True,
#   'last_name': 'Мамонтова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Павел',
#   'id': 361,
#   'is_closed': False,
#   'last_name': 'Кухта',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Елена',
#   'id': 362,
#   'is_closed': False,
#   'last_name': 'Вилинбахова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Юлия',
#   'id': 363,
#   'is_closed': False,
#   'last_name': 'Кудинова-Ли',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Альберт',
#   'id': 364,
#   'is_closed': True,
#   'last_name': 'Александрович',
#   'sex': 2},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 365,
#   'last_name': '',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Вадим',
#   'id': 366,
#   'is_closed': False,
#   'last_name': 'Кириков',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Андрей',
#   'id': 367,
#   'is_closed': False,
#   'last_name': 'Коротков',
#   'sex': 2},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 368,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': False,
#   'first_name': 'Марина',
#   'id': 369,
#   'is_closed': True,
#   'last_name': 'Веселова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Антон',
#   'id': 370,
#   'is_closed': False,
#   'last_name': 'Пертусян',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Виктория',
#   'id': 371,
#   'is_closed': False,
#   'last_name': 'Семченкова',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Маша',
#   'id': 372,
#   'is_closed': True,
#   'last_name': 'Кильдиярова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Светлана',
#   'id': 373,
#   'is_closed': False,
#   'last_name': 'Порошина',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Сергей',
#   'id': 374,
#   'is_closed': False,
#   'last_name': 'Волошин',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Кирилл',
#   'id': 375,
#   'is_closed': False,
#   'last_name': 'Назаренко',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Евгений',
#   'id': 376,
#   'is_closed': True,
#   'last_name': 'Козобродов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Надежда',
#   'id': 377,
#   'is_closed': False,
#   'last_name': 'Маркитантова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Александра',
#   'id': 378,
#   'is_closed': False,
#   'last_name': 'Белая',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Татьяна',
#   'id': 379,
#   'is_closed': False,
#   'last_name': 'Константинова',
#   'sex': 1},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 380,
#   'last_name': '',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Манас',
#   'id': 381,
#   'is_closed': False,
#   'last_name': 'Сираканян',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Роман',
#   'id': 382,
#   'is_closed': False,
#   'last_name': 'Шульман',
#   'sex': 2},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 383,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Петер',
#   'id': 384,
#   'is_closed': False,
#   'last_name': 'Славов',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Алексей',
#   'id': 385,
#   'is_closed': True,
#   'last_name': 'Богданов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Надежда',
#   'id': 386,
#   'is_closed': False,
#   'last_name': 'Супрычева',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Наталья',
#   'id': 387,
#   'is_closed': True,
#   'last_name': 'Белая',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Валентин',
#   'id': 388,
#   'is_closed': False,
#   'last_name': 'Бурцев',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Дмитрий',
#   'id': 389,
#   'is_closed': False,
#   'last_name': 'Кочнев',
#   'sex': 2},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 390,
#   'last_name': '',
#   'sex': 0},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 391,
#   'last_name': '',
#   'sex': 0},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 392,
#   'last_name': '',
#   'sex': 0},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 393,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Vlasta',
#   'id': 394,
#   'is_closed': False,
#   'last_name': 'Solovyeva',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Андрей',
#   'id': 395,
#   'is_closed': True,
#   'last_name': 'Титов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Olga',
#   'id': 396,
#   'is_closed': False,
#   'last_name': 'Dashkevich',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Marina',
#   'id': 397,
#   'is_closed': False,
#   'last_name': 'Slo',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Денис',
#   'id': 398,
#   'is_closed': False,
#   'last_name': 'Щукин',
#   'sex': 2},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 399,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Мария',
#   'id': 400,
#   'is_closed': False,
#   'last_name': 'Давыденко',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Мария',
#   'id': 401,
#   'is_closed': False,
#   'last_name': 'Поляк',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Дмитрий',
#   'id': 402,
#   'is_closed': False,
#   'last_name': 'Королев',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Вера',
#   'id': 403,
#   'is_closed': True,
#   'last_name': 'Веткина',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Эдуард',
#   'id': 404,
#   'is_closed': False,
#   'last_name': 'Николаев',
#   'sex': 2},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 405,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Ольга',
#   'id': 406,
#   'is_closed': False,
#   'last_name': 'Шарко',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Алексей',
#   'id': 407,
#   'is_closed': False,
#   'last_name': 'Железнов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Ирина',
#   'id': 408,
#   'is_closed': False,
#   'last_name': 'Белова',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Виктория',
#   'id': 409,
#   'is_closed': True,
#   'last_name': 'Якунчикова',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Alexander',
#   'id': 410,
#   'is_closed': True,
#   'last_name': 'Obl',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Нина',
#   'id': 411,
#   'is_closed': True,
#   'last_name': 'Отмас',
#   'sex': 1},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 412,
#   'last_name': '',
#   'sex': 0},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 413,
#   'last_name': '',
#   'sex': 0},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 414,
#   'last_name': '',
#   'sex': 0},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 415,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Евгения',
#   'id': 416,
#   'is_closed': False,
#   'last_name': 'Жаржавская',
#   'sex': 1},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 417,
#   'last_name': '',
#   'sex': 0},
#  {'deactivated': 'deleted',
#   'first_name': 'Юлия',
#   'id': 418,
#   'last_name': 'Эрние',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Ярослав',
#   'id': 419,
#   'is_closed': True,
#   'last_name': 'Воронцов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Мария',
#   'id': 420,
#   'is_closed': False,
#   'last_name': 'Телегина',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Екатерина',
#   'id': 421,
#   'is_closed': False,
#   'last_name': 'Щёголева',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Дмитрий',
#   'id': 422,
#   'is_closed': False,
#   'last_name': 'Соколов',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Тимур',
#   'id': 423,
#   'is_closed': True,
#   'last_name': 'Кармов',
#   'sex': 2},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 424,
#   'last_name': '',
#   'sex': 2},
#  {'deactivated': 'banned',
#   'first_name': 'Анна',
#   'id': 425,
#   'last_name': 'Войтенко',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Анна',
#   'id': 426,
#   'is_closed': True,
#   'last_name': 'Коновалова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Алена',
#   'id': 427,
#   'is_closed': False,
#   'last_name': 'Матвейчук',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Александр',
#   'id': 428,
#   'is_closed': True,
#   'last_name': 'Кирпичников',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Михаил',
#   'id': 429,
#   'is_closed': False,
#   'last_name': 'Зубков',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Piotr',
#   'id': 430,
#   'is_closed': False,
#   'last_name': 'Gr',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Мария',
#   'id': 431,
#   'is_closed': True,
#   'last_name': 'Ажинова',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Ný',
#   'id': 432,
#   'is_closed': True,
#   'last_name': 'Lero',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Анастасия',
#   'id': 433,
#   'is_closed': False,
#   'last_name': 'Мальмрус',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Сергей',
#   'id': 434,
#   'is_closed': False,
#   'last_name': 'Золотонос',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Кирилл',
#   'id': 435,
#   'is_closed': True,
#   'last_name': 'Субботин',
#   'sex': 2},
#  {'deactivated': 'banned',
#   'first_name': 'Сергей',
#   'id': 436,
#   'last_name': 'Дюжев',
#   'sex': 2},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 437,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Сергей',
#   'id': 438,
#   'is_closed': False,
#   'last_name': 'Шипилов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Тимофей',
#   'id': 439,
#   'is_closed': False,
#   'last_name': 'Стороженко',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Anastasia',
#   'id': 440,
#   'is_closed': False,
#   'last_name': 'Balashova',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Евгения',
#   'id': 441,
#   'is_closed': False,
#   'last_name': 'Нигматуллина',
#   'sex': 1},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 442,
#   'last_name': '',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Алексей',
#   'id': 443,
#   'is_closed': True,
#   'last_name': 'Юрецкий',
#   'sex': 2},
#  {'deactivated': 'banned',
#   'first_name': 'Алиса',
#   'id': 444,
#   'last_name': 'Иванова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Филипп',
#   'id': 445,
#   'is_closed': False,
#   'last_name': 'Рамбов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Владимир',
#   'id': 446,
#   'is_closed': False,
#   'last_name': 'Богданов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Marianna',
#   'id': 447,
#   'is_closed': False,
#   'last_name': 'Demenkova',
#   'sex': 1},
#  {'deactivated': 'banned',
#   'first_name': 'Никита',
#   'id': 448,
#   'last_name': 'Аникеев',
#   'sex': 2},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 449,
#   'last_name': '',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Марина',
#   'id': 450,
#   'is_closed': False,
#   'last_name': 'Требина',
#   'sex': 1},
#  {'deactivated': 'deleted',
#   'first_name': 'Ксения',
#   'id': 451,
#   'last_name': 'Грюнвальд',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Олег',
#   'id': 452,
#   'is_closed': False,
#   'last_name': 'Желтянников',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Ярославна',
#   'id': 453,
#   'is_closed': False,
#   'last_name': 'Гаген-Торн',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Андрей',
#   'id': 454,
#   'is_closed': False,
#   'last_name': 'Гук',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Евгений',
#   'id': 455,
#   'is_closed': True,
#   'last_name': 'Шехтер',
#   'sex': 2},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 456,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Владимир',
#   'id': 457,
#   'is_closed': False,
#   'last_name': 'Баранов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Сергей',
#   'id': 458,
#   'is_closed': False,
#   'last_name': 'Нагапетян',
#   'sex': 2},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 459,
#   'last_name': '',
#   'sex': 0},
#  {'deactivated': 'banned',
#   'first_name': 'Ilya',
#   'id': 460,
#   'last_name': 'Dneprovsky',
#   'sex': 2},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 461,
#   'last_name': '',
#   'sex': 0},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 462,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Людмила',
#   'id': 463,
#   'is_closed': False,
#   'last_name': 'Захарова',
#   'sex': 1},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 464,
#   'last_name': '',
#   'sex': 2},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 465,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Anastasia',
#   'id': 466,
#   'is_closed': False,
#   'last_name': 'Mikhaylova',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Игорь',
#   'id': 467,
#   'is_closed': False,
#   'last_name': 'Перекопский',
#   'sex': 2},
#  {'deactivated': 'banned',
#   'first_name': 'Паша',
#   'id': 468,
#   'last_name': 'Кипелов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Екатерина',
#   'id': 469,
#   'is_closed': False,
#   'last_name': 'Пушкина',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Антон',
#   'id': 470,
#   'is_closed': False,
#   'last_name': 'Зайцев',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Дмитрий',
#   'id': 471,
#   'is_closed': False,
#   'last_name': 'Никончук',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Евгения',
#   'id': 472,
#   'is_closed': False,
#   'last_name': 'Захарова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Алёна',
#   'id': 473,
#   'is_closed': False,
#   'last_name': 'Тайлер',
#   'sex': 1},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 474,
#   'last_name': '',
#   'sex': 0},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 475,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': False,
#   'first_name': 'Лена',
#   'id': 476,
#   'is_closed': True,
#   'last_name': 'Самуйлова',
#   'sex': 1},
#  {'deactivated': 'banned',
#   'first_name': 'Алексей',
#   'id': 477,
#   'last_name': 'Комаров',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Кирилл',
#   'id': 478,
#   'is_closed': True,
#   'last_name': 'Мошков',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Виктория',
#   'id': 479,
#   'is_closed': False,
#   'last_name': 'Стацевич',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Yarik',
#   'id': 480,
#   'is_closed': True,
#   'last_name': 'Markov',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Софья',
#   'id': 481,
#   'is_closed': False,
#   'last_name': 'Чебанова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Юлия',
#   'id': 482,
#   'is_closed': False,
#   'last_name': 'Васильева',
#   'sex': 1},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 483,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Юлия',
#   'id': 484,
#   'is_closed': False,
#   'last_name': 'Нураева',
#   'sex': 1},
#  {'deactivated': 'banned',
#   'first_name': 'Дарья',
#   'id': 485,
#   'last_name': 'Павлова',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Наталия',
#   'id': 486,
#   'is_closed': True,
#   'last_name': 'Юрасова',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Светлана',
#   'id': 487,
#   'is_closed': True,
#   'last_name': 'Каткова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Алексей',
#   'id': 488,
#   'is_closed': False,
#   'last_name': 'Леонидович',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Александра',
#   'id': 489,
#   'is_closed': True,
#   'last_name': 'Родионова',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Елена',
#   'id': 490,
#   'is_closed': True,
#   'last_name': 'Ящике',
#   'sex': 1},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 491,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Кирилл',
#   'id': 492,
#   'is_closed': False,
#   'last_name': 'Ширяев',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Дарья',
#   'id': 493,
#   'is_closed': False,
#   'last_name': 'Монихарт',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Анна',
#   'id': 494,
#   'is_closed': True,
#   'last_name': 'Бабурова',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Михаил',
#   'id': 495,
#   'is_closed': True,
#   'last_name': 'Кадобнов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Григорий',
#   'id': 496,
#   'is_closed': False,
#   'last_name': 'Малыгин',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Светлана',
#   'id': 497,
#   'is_closed': True,
#   'last_name': 'Лапина',
#   'sex': 1},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 498,
#   'last_name': '',
#   'sex': 1},
#  {'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 499,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Анонимный пользователь',
#   'id': 500,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 2}]
# 0.48

# %% [markdown]
# # СБОР ИНФОРМАЦИИ ИЗ ГРУПП
#
# В одном из предыдущих юнитов в качестве примера мы собрали информацию о небольшом количестве пользователей. Теперь перейдём к более реальной задаче — сбору данных о пользователях группы ВКонтакте.
#
# Стоит отметить, что есть много сервисов, которые выгружают похожую статистику из соцсетей. Однако им свойственны недостатки универсальных решений:
#
# не учитываются все особенности вашего проекта;
# используется фиксированный набор метрик, дополнительную обработку данных приходится делать вам;
# не всегда бесплатны и вряд ли позволят работать с большими объёмами данных.
# Теперь мы научимся считать произвольные метрики групп, собирая данные из API и работая с двумя ограничениями, которые свойственны практически всем системам:
#
# ограничение на количество вызовов в единицу времени;
# ограничение на количество выгружаемых строк за один запрос.
# Ограничение на количество запросов в единицу времени сделано для того, чтобы избежать чрезмерной нагрузки на серверы системы. В ряде случаев небольшое количество отчётов можно выгрузить и уложиться в действующий лимит.
#
# Однако второе ограничение не удастся обойти в случае выгрузки больших отчётов. Например, чтобы получить список всех пользователей популярной группы, серверу, возможно, придётся отправить ответ, содержащий миллионы записей.
#
# Давайте рассмотрим, как работать с этими ограничениями на примере выгрузки списка пользователей группы https://vk.com/vk социальной сети ВКонтакте.
#
# Обратимся к документации, чтобы узнать, какие методы нам доступны для групп, — для получения списка пользователей группы доступен метод groups.getMembers.
#
# Согласно документации, обязательным параметром данного метода является group_id — идентификатор, или короткое имя, группы. В нашем случае это vk: https://vk.com/vk. Протестируем, как работает метод в самом простом случае, — получим id участников группы:

# %%
import requests # Импортируем модуль requests
token = 'aa503394aa503394aa5033946ea9418302aaa50aa503394c9d7072cfa516048de32f784' 
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес обращения
params = {'group_id': 'vk', 'v': 5.95, 'access_token': token} # Формируем строку параметров
response = requests.get(url, params = params) # Посылаем запрос
data = response.json() # Ответ сохраняем в переменной data в формате словаря


#По ключу count мы можем получить общее число участников группы, а список по ключу items хранит их id. Посмотрим на него поближе:

print(len(data['response']['items'])) # Выводим на экран количество элементов словаря
# Out:
# 1000

# %% [markdown]
# Мы видим, что всего пользователей в группе больше 11 миллионов, а получили мы только первую тысячу пользователей группы. По информации, указанной в документации о параметре count, это максимум, который может отдать API за один раз.
#
# Для получения следующей тысячи пользователей можно воспользоваться параметром offset (с англ. смещение), который передвинет начало отсчёта. Для выгрузки всех пользователей группы будем в цикле выгружать по 1000 пользователей (count будет всегда равен 1000), увеличивая смещение offset на величину count.
#
# Для тренировки напишем цикл выгрузки первых 20 пользователей со значением count=5. Иными словами, мы будем выгружать по пять пользователей за запрос до тех пор, пока не получим информацию о 20 пользователях.
#
# Давайте выведем на экран первые 20 пользователей из нашей первой попытки получить информацию о 1000 пользователей, чтобы мы могли сверить результат выгрузки из 20 пользователей:

# %%
users_for_checking = data['response']['items'][:20] # Загружаем в переменную информацию об id первых 20 пользователей в виде списка
print(users_for_checking) 
#Теперь используем count и offset, чтобы получить те же id по пять за раз:

import requests # Импортируем модуль requests
token = 'aa503394aa503394aa5033946ea9418302aaa50aa503394c9d7072cfa516048de32f784' 
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес обращения
count = 5 
offset = 0 
user_ids = [] 
max_count = 20 
while offset < max_count: 
    # Будем выгружать по count=5 пользователей, 
    # начиная с того места, где закончили на предыдущей итерации (offset) 
    print('Выгружаю {} пользователей с offset = {}'.format(count, offset))   
    params = {'group_id': 'vk', 'v': 5.95, 'count': count, 'offset': offset, 'access_token': token} 
    response = requests.get(url, params = params) 
    data = response.json() 
    user_ids += data['response']['items'] 
    # Увеличиваем смещение на количество строк, которое мы уже выгрузили 
    offset += count 
print(user_ids) 

#Сравним списки, полученные двумя способами:

print(user_ids == users_for_checking)
# Out:
# [6, 19, 47, 54, 79, 177, 198, 212, 219, 239, 243, 345, 407, 450, 467, 485, 510, 550, 619, 640]
# Выгружаю 5 пользователей с offset = 0
# Выгружаю 5 пользователей с offset = 5
# Выгружаю 5 пользователей с offset = 10
# Выгружаю 5 пользователей с offset = 15
# [6, 19, 47, 54, 79, 177, 198, 212, 219, 239, 243, 345, 407, 450, 467, 485, 510, 550, 619, 640]
# True

# %% [markdown]
# Так как результат сравнения — True, списки идентичны. Значит, второй способ работает корректно. Теперь мы можем получить данные обо всех пользователях, выставив count = 1000 и max_count = data['response']['count'].
#
# ## ОГРАНИЧЕНИЕ ПО ЧАСТОТЕ ЗАПРОСОВ
#
# → В API часто добавляют ограничение по частоте запросов, чтобы отдельно взятые пользователи слишком сильно не перегружали сервер. Подобное ограничение есть и у ВКонтакте — в документации указано, что можно делать не более трёх запросов в секунду.
#
# Чтобы не следить за частотой отправки запросов с секундомером в руках, мы можем после каждого запроса делать паузу. В этом случае, даже если код будет выполняться на самом быстром компьютере, мы не нарушим установленное ограничение, так как периодичность отправки запросов будет искусственно замедлена.
#
# Воспользуемся библиотекой time и методом sleep, с помощью которого мы можем добавить паузу, например в 0.5 секунд, после каждого запроса:

# %%
import requests # Импортируем модуль requests
import time # Импортируем модуль time
token = 'aa503394aa503394aa5033946ea9418302aaa50aa503394c9d7072cfa516048de32f784' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес страницы, к которой делаем запрос
count = 1000 
offset = 0  
user_ids = []  
while offset < 5000: 
    params = {'group_id': 'vk', 'v': 5.95, 'count': count, 'offset': offset, 'access_token': token} 
    response = requests.get(url, params = params) 
    data = response.json() 
    user_ids += data['response']['items'] 
    offset += count 
    print('Ожидаю 0.5 секунды...') 
    time.sleep(0.5) 
print('Цикл завершен, offset =',offset)
# Out:
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Цикл завершен, offset = 5000

# %% [markdown]
# ## ЛАЙКИ, РЕПОСТЫ И КОММЕНТАРИИ
#
# Через API новостной ленты ВКонтакте мы можем получить информацию о взаимодействии с сообщениями в ленте.
#
# Для примера продолжим работать с группой https://vk.com/vk и рассмотрим последние 1000 сообщений в новостной ленте.
#
# Для получения информации о сообщениях на стене в API ВКонтакте предусмотрен метод wall.get. Применим его:

# %%
import requests # Импортируем модуль requests
from pprint import pprint # Импортируем функцию pprint()
token = 'aa503394aa503394aa5033946ea9418302aaa50aa503394c9d7072cfa516048de32f784' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/wall.get' # Указываем адрес страницы, к которой делаем запрос
params = {'domain': 'vk', 'filter': 'owner', 'count': 1000, 'offset': 0, 'access_token': token, 'v': 5.95} 
response = requests.get(url, params = params) 
pprint(response.json())

# %%
response.json()['response']['items'][0]

# %% [markdown]
# В полях comments, likes и reposts содержится статистика по взаимодействию с сообщением пользователей (на момент получения информации) — число комментариев, лайков и репостов.
#
# Давайте соберём итоговую статистику для последних десяти непустых сообщений в словарь stats. В качестве ключа будем использовать начало сообщения (если начало сообщения пустое, то информацию о таком сообщении проигнорируем), в качестве значения — список с тремя интересующими нас метриками и временем публикации (комментарии, лайки, репосты, дата публикации):

# %%
stats = {} 
count_post = 0 # Счётчик «непустых» сообщений
for record in response.json()['response']['items'][:]:
    title = record['text'][:30] 
    if title: 
        stats[title] = [record['comments']['count'], record['likes']['count'], record['reposts']['count'], record['date']] 
        count_post += 1 
    if count_post < 10: 
        continue 
    else: 
        break 
pprint(stats)
#Итак, на момент создания учебных материалов десять последних непустых сообщений в группе имели следующую статистику:
# Out:
# {'VK Видео объединяет ролики, тр': [460, 1364, 595, 1667813760],
#  'VK Мессенджер стал самым попул': [407, 1140, 337, 1669042337],
#  'В VK Мессенджере большое обнов': [496, 1747, 1000, 1667986517],
#  'Как думаете, сколько людей пос': [345, 1388, 445, 1668703817],
#  'Как развивать медиа ВКонтакте?': [415, 1726, 724, 1668422160],
#  'Нейросети помогают не только с': [786, 1372, 842, 1669277367],
#  'Отправляете голосовые, когда н': [240, 589, 81, 1669649531],
#  'Подводим [https://vk.com/press': [615, 2223, 733, 1668077609],
#  'Теперь в профиле можно закрепи': [273, 857, 281, 1669722855],
#  'Хотим поделиться приятными нов': [210, 803, 236, 1669117035]}

# %% [markdown]
# Вы рассмотрели базовое взаимодействие с пользователями и группами. ВКонтакте предоставляет достаточно широкие возможности в своём API: всё, что можно делать вручную через браузер, доступно и в API.
#
# ДОПОЛНИТЕЛЬНО
#
# Если вы размещаете рекламу во ВКонтакте, то можно выгружать всю статистику через ads API.
#
# Полный список методов ВКонтакте можно посмотреть в документации.
#
# ДРУГИЕ API
#
# Вы познакомились с интерфейсами прикладного программирования — API (на примере API социальной сети ВКонтакте).
#
# API для разработчиков предоставляют и многие другие платформы. Вот список, пожалуй, самых популярных из них:
#
# Google Maps API
# YouTube API
# Twitter API
# Facebook API
# Информацию о сторонних API можно найти в каталоге Web API. Также можно воспользоваться интернет-поиском, указав в строке поиска, например, «курсы валют API» или «прогноз погоды api», — среди первых результатов выдачи чаще всего с лёгкостью можно найти ссылки на необходимый функционал.
